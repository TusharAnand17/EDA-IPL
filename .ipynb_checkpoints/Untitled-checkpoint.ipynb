# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('C:\Computer Science\Data Analytics\IPL\IPL Matches 2008-2020.csv')
df
# Out:
#           id        city        date player_of_match  \
# 0     335982   Bangalore  2008-04-18     BB McCullum
# 1     335983  Chandigarh  2008-04-19      MEK Hussey
# 2     335984       Delhi  2008-04-19     MF Maharoof
# 3     335985      Mumbai  2008-04-20      MV Boucher
# 4     335986     Kolkata  2008-04-20       DJ Hussey
# ..       ...         ...         ...             ...
# 811  1216547       Dubai  2020-09-28  AB de Villiers
# 812  1237177       Dubai  2020-11-05       JJ Bumrah
# 813  1237178   Abu Dhabi  2020-11-06   KS Williamson
# 814  1237180   Abu Dhabi  2020-11-08      MP Stoinis
# 815  1237181       Dubai  2020-11-10        TA Boult
#
#                                           venue  neutral_venue  \
# 0                         M Chinnaswamy Stadium              0
# 1    Punjab Cricket Association Stadium, Mohali              0
# 2                              Feroz Shah Kotla              0
# 3                              Wankhede Stadium              0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 816 entries, 0 to 815
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               816 non-null    int64
#  1   city             803 non-null    object
#  2   date             816 non-null    object
#  3   player_of_match  812 non-null    object
#  4   venue            816 non-null    object
#  5   neutral_venue    816 non-null    int64
#  6   team1            816 non-null    object
#  7   team2            816 non-null    object
#  8   toss_winner      816 non-null    object
#  9   toss_decision    816 non-null    object
#  10  winner           812 non-null    object
#  11  result           812 non-null    object
#  12  result_margin    799 non-null    float64
#  13  eliminator       812 non-null    object
#  14  method           19 non-null     object
#  15  umpire1          816 non-null    object
# ...

# %%
df.isnull().sum()
# Out:
# id                   0
# city                13
# date                 0
# player_of_match      4
# venue                0
# neutral_venue        0
# team1                0
# team2                0
# toss_winner          0
# toss_decision        0
# winner               4
# result               4
# result_margin       17
# eliminator           4
# method             797
# umpire1              0
# umpire2              0
# dtype: int64

# %%
df.drop(columns=['method'],axis = 1,inplace = True)

# %%
df
# Out:
#           id        city        date player_of_match  \
# 0     335982   Bangalore  2008-04-18     BB McCullum
# 1     335983  Chandigarh  2008-04-19      MEK Hussey
# 2     335984       Delhi  2008-04-19     MF Maharoof
# 3     335985      Mumbai  2008-04-20      MV Boucher
# 4     335986     Kolkata  2008-04-20       DJ Hussey
# ..       ...         ...         ...             ...
# 811  1216547       Dubai  2020-09-28  AB de Villiers
# 812  1237177       Dubai  2020-11-05       JJ Bumrah
# 813  1237178   Abu Dhabi  2020-11-06   KS Williamson
# 814  1237180   Abu Dhabi  2020-11-08      MP Stoinis
# 815  1237181       Dubai  2020-11-10        TA Boult
#
#                                           venue  neutral_venue  \
# 0                         M Chinnaswamy Stadium              0
# 1    Punjab Cricket Association Stadium, Mohali              0
# 2                              Feroz Shah Kotla              0
# 3                              Wankhede Stadium              0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 816 entries, 0 to 815
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               816 non-null    int64
#  1   city             803 non-null    object
#  2   date             816 non-null    object
#  3   player_of_match  812 non-null    object
#  4   venue            816 non-null    object
#  5   neutral_venue    816 non-null    int64
#  6   team1            816 non-null    object
#  7   team2            816 non-null    object
#  8   toss_winner      816 non-null    object
#  9   toss_decision    816 non-null    object
#  10  winner           812 non-null    object
#  11  result           812 non-null    object
#  12  result_margin    799 non-null    float64
#  13  eliminator       812 non-null    object
#  14  umpire1          816 non-null    object
#  15  umpire2          816 non-null    object
# dtypes: float64(1), int64(2), object(13)
# ...

# %% [markdown]
# # Most win in IPL

# %%
df = df.replace(['Rising Pune Supergiants'],'Rising Pune Supergiant')

# %%
mostWin = df['winner'].value_counts()
mostWin = pd.DataFrame(mostWin)
mostWin
# Out:
#                              winner
# Mumbai Indians                  120
# Chennai Super Kings             106
# Kolkata Knight Riders            99
# Royal Challengers Bangalore      91
# Kings XI Punjab                  88
# Rajasthan Royals                 81
# Delhi Daredevils                 67
# Sunrisers Hyderabad              66
# Deccan Chargers                  29
# Delhi Capitals                   19
# Rising Pune Supergiant           15
# Gujarat Lions                    13
# Pune Warriors                    12
# Kochi Tuskers Kerala              6

# %%
data = np.array(mostWin['winner'])
label = [i for i in mostWin.index]
plt.figure(figsize = (10,12))
plt.pie(data,labels = label,autopct = '%1.1f%%');

# %% [markdown]
# # Most winner in eliminator

# %%
eliminatorwinner = df[df['eliminator']=='Y']
eliminatorwinner = eliminatorwinner[['winner','eliminator']]
sns.countplot(x = 'winner',data = eliminatorwinner);
plt.xticks(rotation= 30,ha= 'right');
plt.xlabel('Teams');
plt.ylabel('Most No. of Wins in Eliminator');

# %% [markdown]
# # Toss decision

# %%
tossdecisionteam = df.groupby(df['toss_winner'],as_index=False)[['toss_decision']].count()
tossdecisionteam

batdecision = df[df['toss_decision']=='bat']
batdecision = batdecision[['toss_decision','toss_winner']]
batdecision=batdecision.groupby('toss_winner',as_index=False)[['toss_decision']].count()
batdecision.rename(columns={'toss_decision':'bat'},inplace=True)

fielddecision = df[df['toss_decision']=='field']
fileddecision = fielddecision[['toss_decision','toss_winner']]
fielddecision=fielddecision.groupby('toss_winner',as_index=False)[['toss_decision']].count()
fielddecision.rename(columns={'toss_decision':'field'},inplace=True)

# %%
tossdecisionteam['toss_decision']
# Out:
#                     toss_winner  toss_decision
# 0           Chennai Super Kings             97
# 1               Deccan Chargers             43
# 2                Delhi Capitals             20
# 3              Delhi Daredevils             80
# 4                 Gujarat Lions             15
# 5               Kings XI Punjab             85
# 6          Kochi Tuskers Kerala              8
# 7         Kolkata Knight Riders             98
# 8                Mumbai Indians            106
# 9                 Pune Warriors             20
# 10             Rajasthan Royals             87
# 11       Rising Pune Supergiant             13
# 12  Royal Challengers Bangalore             87
# 13          Sunrisers Hyderabad             57

# %%
batdecision
# Out:
#                     toss_winner  bat
# 0           Chennai Super Kings   51
# 1               Deccan Chargers   24
# 2                Delhi Capitals    7
# 3              Delhi Daredevils   29
# 4                 Gujarat Lions    1
# 5               Kings XI Punjab   27
# 6          Kochi Tuskers Kerala    3
# 7         Kolkata Knight Riders   34
# 8                Mumbai Indians   48
# 9                 Pune Warriors   11
# 10             Rajasthan Royals   34
# 11       Rising Pune Supergiant    3
# 12  Royal Challengers Bangalore   24
# 13          Sunrisers Hyderabad   24

# %%
fielddecision
# Out:
#                     toss_winner  field
# 0           Chennai Super Kings     46
# 1               Deccan Chargers     19
# 2                Delhi Capitals     13
# 3              Delhi Daredevils     51
# 4                 Gujarat Lions     14
# 5               Kings XI Punjab     58
# 6          Kochi Tuskers Kerala      5
# 7         Kolkata Knight Riders     64
# 8                Mumbai Indians     58
# 9                 Pune Warriors      9
# 10             Rajasthan Royals     53
# 11       Rising Pune Supergiant     10
# 12  Royal Challengers Bangalore     63
# 13          Sunrisers Hyderabad     33

# %%
final = pd.merge(tossdecisionteam,batdecision,on="toss_winner")
Fullfinal = pd.merge(final,fielddecision,on='toss_winner')
Fullfinal
# Out:
#                     toss_winner  toss_decision  bat  field
# 0           Chennai Super Kings             97   51     46
# 1               Deccan Chargers             43   24     19
# 2                Delhi Capitals             20    7     13
# 3              Delhi Daredevils             80   29     51
# 4                 Gujarat Lions             15    1     14
# 5               Kings XI Punjab             85   27     58
# 6          Kochi Tuskers Kerala              8    3      5
# 7         Kolkata Knight Riders             98   34     64
# 8                Mumbai Indians            106   48     58
# 9                 Pune Warriors             20   11      9
# 10             Rajasthan Royals             87   34     53
# 11       Rising Pune Supergiant             13    3     10
# 12  Royal Challengers Bangalore             87   24     63
# 13          Sunrisers Hyderabad             57   24     33

# %%
plt.plot(Fullfinal['toss_winner'],Fullfinal['bat'])
plt.plot(Fullfinal['toss_winner'],Fullfinal['field'])
plt.legend(['bat','field']);
plt.xticks(rotation = 90);

# %%
famousVenuename = df['venue'].value_counts().index[0:10]
famousVenuecount = df['venue'].value_counts().values[0:10]
famousvenue = sns.barplot(x=famousVenuename,y = famousVenuecount)
plt.xticks(rotation = 90,ha='right');

for bars in famousvenue.containers:
    famousvenue.bar_label(bars)
    
plt.xlabel('Venue')
plt.ylabel('Match Played')
plt.title('Most Famous Venue');

# %%
sns.barplot(x = df['umpire1'].value_counts().index[0:5],y = df['umpire1'].value_counts().values[0:5]);
plt.xticks(rotation = 45,ha='right');

# %%
sns.barplot(x = df['umpire2'].value_counts().index[0:5],y = df['umpire2'].value_counts().values[0:5]);
plt.xticks(rotation = 45,ha='right');

# %%
valuablePlayer = pd.DataFrame(df['player_of_match'].value_counts())
valuablePlayer
# Out:
#                 player_of_match
# AB de Villiers               23
# CH Gayle                     22
# RG Sharma                    18
# DA Warner                    17
# MS Dhoni                     17
# ...                         ...
# S Anirudha                    1
# M Kartik                      1
# R McLaren                     1
# RJ Harris                     1
# PJ Cummins                    1
#
# [233 rows x 1 columns]

# %% [markdown]
# # No. of times team won toss and match together

# %%
team_name = input("Enter the Team Name: ")
wonWhenTossWon = df[(df['toss_winner']==team_name) & (df['winner']==team_name)]
wonWhenTossWon=wonWhenTossWon[['id','team1','team2','toss_winner','toss_decision','winner','venue']]
wonWhenTossWon
print(f"Out of {tossdecisionteam[tossdecisionteam['toss_winner']==team_name]['toss_decision'].values[0]} times {team_name} won {len(wonWhenTossWon)} times when they won the toss")
# Out:
# Enter the Team Name: Mumbai Indians
# Out of 106 times Mumbai Indians won 61 times when they won the toss
